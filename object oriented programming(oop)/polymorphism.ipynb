# %% [markdown]
# ### Polymorphism:- Polymorphism means "many forms".It allows the same method name to have different implementations depending on the object.

# %%
class Cat:
    def sound(self):
        return "Meow"

class Dog:
    def sound(self):
        return "Bark"

for animal in (Cat(), Dog()):
    print(animal.sound())
# Out:
# Meow
# Bark
